# %% [markdown]
# # import libraries

# %%
import numpy as np
import math
import cv2
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# # create classifier

# %%
  face_classifier=cv2.CascadeClassifier('C:\\Users\TARUN VERMA\Desktop\Object Detction\Haarcascades\haarcascade_frontalface_default.xml')

# %% [markdown]
# # open image

# %%
#x='C:\\Users\TARUN VERMA\Desktop\Object Detction\Face Detection\Tarun.jpg'
x=input('Please enter the location')
z=input('Please enter the full name of the image')
y=x.find(':')
x=x[:y+1]+'\\'+x[y+1:]+'\\'+z
image = cv2.imread(x)
fix_img = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
plt.imshow(fix_img)
# Out:
# Please enter the locationC:\Users\TARUN VERMA\Pictures\Saved Pictures
# Please enter the full name of the image2066907.jpg

# %% [markdown]
# # Detect Faces

# %%
faces = face_classifier.detectMultiScale(image, 1.3, 5)

# %% [markdown]
# # No Face Detected

# %%
if faces is ():
    print("Not Found")
# Out:
# <>:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <ipython-input-23-8b2449959bce>:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if faces is ():

# %% [markdown]
# # It's a kind of Magic

# %%
def detect_face(fix_img):
    face_rects = face_classifier.detectMultiScale(fix_img)
    for(x,y,w,h) in face_rects:
        cv2.rectangle(fix_img,(x,y),(x+w,y+h),(255,0,0),10)
    return fix_img

# %%
result = detect_face(fix_img)
plt.imshow(result)
